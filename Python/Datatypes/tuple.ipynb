# %% [markdown]
# # Tuples:
# Tuples are immutable datatypes, all the other features are similar to list

# %%
tup1=(3,"Hello",True,34.56,3)
print(len(tup1))
print(list(tup1))
print(tup1[1:3])
print(tup1[-3])
tup1.count(3)
# Out:
# 5
# [3, 'Hello', True, 34.56, 3]
# ('Hello', True)
# True
# 2
